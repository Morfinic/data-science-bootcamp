# %% [markdown]
# <a href="https://colab.research.google.com/github/Morfinic/data-science-bootcamp/blob/main/02_analiza_danych/04_laczenie_danych.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Wczytywanie danych**

# %%
import pandas as pd

# %%
def fetch_financial_data(company='AMZN'):
    """
    This function fetch stock market quotations.
    """
    import pandas_datareader.data as web
    return web.DataReader(name=company, data_source='stooq')

apple = fetch_financial_data('AAPL')
amazon = fetch_financial_data('AMZN')
google = fetch_financial_data('GOOGL')
uber = fetch_financial_data('UBER')

# %%
uber.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 817 entries, 2022-08-05 to 2019-05-10
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    817 non-null    float64
#  1   High    817 non-null    float64
#  2   Low     817 non-null    float64
#  3   Close   817 non-null    float64
#  4   Volume  817 non-null    int64
# dtypes: float64(4), int64(1)
# memory usage: 38.3 KB

# %%
apple.head()
# Out:
#                Open    High     Low   Close    Volume
# Date
# 2022-08-05  163.210  165.85  163.00  165.35  56696985
# 2022-08-04  166.005  167.19  164.43  165.81  55474144
# 2022-08-03  160.840  166.59  160.75  166.13  82507488
# 2022-08-02  160.100  162.41  159.63  160.01  59907025
# 2022-08-01  161.010  163.59  160.89  161.51  67829379

# %% [markdown]
# # **Preprocessing**

# %%
apple.columns = ["apple_" + col.lower() for col in apple.columns]
amazon.columns = ["amazon_" + col.lower() for col in amazon.columns]
google.columns = ["google_" + col.lower() for col in google.columns]
uber.columns = ["uber_" + col.lower() for col in uber.columns]

# %%
apple.head()
# Out:
#             apple_open  apple_high  apple_low  apple_close  apple_volume
# Date
# 2022-08-05     163.210      165.85     163.00       165.35      56696985
# 2022-08-04     166.005      167.19     164.43       165.81      55474144
# 2022-08-03     160.840      166.59     160.75       166.13      82507488
# 2022-08-02     160.100      162.41     159.63       160.01      59907025
# 2022-08-01     161.010      163.59     160.89       161.51      67829379

# %% [markdown]
# # **Konkatenacja danych**

# %%
df = pd.concat(objs=[apple, amazon, google, uber], axis=1)

# %%
df.describe()
# Out:
#         apple_open   apple_high    apple_low  apple_close  apple_volume  \
# count  1258.000000  1258.000000  1258.000000  1258.000000  1.258000e+03
# mean     88.104807    89.150220    87.120320    88.184167  1.217665e+08
# std      46.342384    46.950676    45.749497    46.380674  5.656804e+07
# min      34.849000    35.266000    34.368000    34.414000  4.111250e+07
# 25%      45.488750    45.892250    45.106500    45.427250  8.434297e+07
# 50%      68.932500    69.909500    68.451000    69.262500  1.072421e+08
# 75%     132.075000   133.355000   130.412500   131.802500  1.420290e+08
# max     182.130000   182.440000   178.630000   181.510000  4.333866e+08
#
#        amazon_open  amazon_high   amazon_low  amazon_close  amazon_volume  \
# count  1258.000000  1258.000000  1258.000000   1258.000000   1.258000e+03
# mean    115.209581   116.545404   113.736937    115.158253   8.638249e+07
# std      39.775499    40.252810    39.236486     39.704084   4.099782e+07
# min      47.000000    47.431500    46.587500     46.930000   1.762674e+07
# 25%      85.336125    86.271750    84.355250     85.339500   5.881648e+07
# 50%      98.662750    99.808250    97.745250     98.767000   7.478215e+07
# 75%     158.328500   159.931000   156.225000    158.093500   1.022881e+08
# max     187.200000   188.654000   184.840000    186.570000   3.310520e+08
#
#        google_open  google_high   google_low  google_close  google_volume  \
# count  1258.000000  1258.000000  1258.000000   1258.000000   1.258000e+03
# mean     81.614808    82.488393    80.738212     81.639938   3.532036e+07
# std      31.780225    32.098035    31.396322     31.745483   1.601958e+07
00 186322536.00

# %%
df.corr()
# Out:
#                apple_open  apple_high  apple_low  apple_close  apple_volume  \
# apple_open           1.00        1.00       1.00         1.00         -0.29
# apple_high           1.00        1.00       1.00         1.00         -0.28
# apple_low            1.00        1.00       1.00         1.00         -0.30
# apple_close          1.00        1.00       1.00         1.00         -0.29
# apple_volume        -0.29       -0.28      -0.30        -0.29          1.00
# amazon_open          0.89        0.89       0.89         0.89         -0.21
# amazon_high          0.89        0.89       0.89         0.89         -0.21
# amazon_low           0.88        0.88       0.88         0.88         -0.22
# amazon_close         0.89        0.89       0.89         0.89         -0.22
# amazon_volume       -0.21       -0.21      -0.22        -0.21          0.57
# google_open          0.95        0.95       0.95         0.95         -0.36
# google_high          0.95        0.95       0.95         0.95         -0.36
# google_low           0.95        0.95       0.95         0.95         -0.37
# google_close         0.95        0.95       0.95         0.95         -0.36
# google_volume       -0.08       -0.07      -0.08        -0.08          0.50
# uber_open            0.21        0.20       0.21         0.21         -0.28
# uber_high            0.22        0.21       0.22         0.21         -0.27
# uber_low             0.21        0.20       0.21         0.21         -0.30
# uber_close           0.21        0.21       0.21         0.21         -0.28
# uber_volume          0.13        0.13       0.12         0.13          0.24
#
#                amazon_open  amazon_high  amazon_low  amazon_close  \
# apple_open            0.89         0.89        0.88          0.89
# apple_high            0.89         0.89        0.88          0.89
# apple_low             0.89         0.89        0.88          0.89
# apple_close           0.89         0.89        0.88          0.89
# apple_volume         -0.21        -0.21       -0.22         -0.22
# amazon_open           1.00         1.00        1.00          1.00
# amazon_high           1.00         1.00        1.00          1.00
# amazon_low            1.00         1.00        1.00          1.00
# amazon_close          1.00         1.00        1.00          1.00
# amazon_volume        -0.17        -0.15       -0.18         -0.17
# google_open           0.84         0.84        0.84          0.84
# google_high           0.84         0.84        0.84          0.84
# google_low            0.84         0.84        0.84          0.84
# google_close          0.84         0.84        0.84          0.84
# google_volume        -0.09        -0.08       -0.10         -0.09
# uber_open             0.55         0.54        0.56          0.55
# uber_high             0.55         0.54        0.56          0.55
# uber_low              0.55         0.54        0.56          0.55
# uber_close            0.55         0.54        0.56          0.55
# uber_volume          -0.06        -0.05       -0.07         -0.06
#
#                amazon_volume  google_open  google_high  google_low  \
# apple_open             -0.21         0.95         0.95        0.95
# apple_high             -0.21         0.95         0.95        0.95
# apple_low              -0.22         0.95         0.95        0.95
# apple_close            -0.21         0.95         0.95        0.95
# apple_volume            0.57        -0.36        -0.36       -0.37
# amazon_open            -0.17         0.84         0.84        0.84
# amazon_high            -0.15         0.84         0.84        0.84
# amazon_low             -0.18         0.84         0.84        0.84
# amazon_close           -0.17         0.84         0.84        0.84
# amazon_volume           1.00        -0.25        -0.24       -0.25
# google_open            -0.25         1.00         1.00        1.00
# google_high            -0.24         1.00         1.00        1.00
# google_low             -0.25         1.00         1.00        1.00
# google_close           -0.25         1.00         1.00        1.00
# google_volume           0.60        -0.11        -0.11       -0.13
# uber_open              -0.23         0.27         0.26        0.28
# uber_high              -0.22         0.27         0.27        0.28
# uber_low               -0.25         0.27         0.26        0.28
# uber_close             -0.24         0.27         0.26        0.27
# uber_volume             0.24         0.10         0.11        0.10
#
#                google_close  google_volume  uber_open  uber_high  uber_low  \
# apple_open             0.95          -0.08       0.21       0.22      0.21
# apple_high             0.95          -0.07       0.20       0.21      0.20
# apple_low              0.95          -0.08       0.21       0.22      0.21
# apple_close            0.95          -0.08       0.21       0.21      0.21
# apple_volume          -0.36           0.50      -0.28      -0.27     -0.30
# amazon_open            0.84          -0.09       0.55       0.55      0.55
# amazon_high            0.84          -0.08       0.54       0.54      0.54
# amazon_low             0.84          -0.10       0.56       0.56      0.56
# amazon_close           0.84          -0.09       0.55       0.55      0.55
# amazon_volume         -0.25           0.60      -0.23      -0.22     -0.25
# google_open            1.00          -0.11       0.27       0.27      0.27
# google_high            1.00          -0.11       0.26       0.27      0.26
# google_low             1.00          -0.13       0.28       0.28      0.28
# google_close           1.00          -0.12       0.27       0.27      0.27
# google_volume         -0.12           1.00      -0.22      -0.20     -0.23
# uber_open              0.27          -0.22       1.00       1.00      1.00
# uber_high              0.27          -0.20       1.00       1.00      1.00
# uber_low               0.27          -0.23       1.00       1.00      1.00
# uber_close             0.27          -0.22       0.99       1.00      1.00
# uber_volume            0.10           0.26      -0.26      -0.24     -0.28
#
#                uber_close  uber_volume
# apple_open           0.21         0.13
# apple_high           0.21         0.13
# apple_low            0.21         0.12
# apple_close          0.21         0.13
# apple_volume        -0.28         0.24
# amazon_open          0.55        -0.06
# amazon_high          0.54        -0.05
# amazon_low           0.56        -0.07
# amazon_close         0.55        -0.06
# amazon_volume       -0.24         0.24
# google_open          0.27         0.10
# google_high          0.26         0.11
# google_low           0.27         0.10
# google_close         0.27         0.10
# google_volume       -0.22         0.26
# uber_open            0.99        -0.26
# uber_high            1.00        -0.24
# uber_low             1.00        -0.28
# uber_close           1.00        -0.26
# uber_volume         -0.26         1.00

# %%
closes = [col for col in df.columns if col.endswith("close") or col.endswith("volume")]
closes
# Out:
# ['apple_close',
#  'apple_volume',
#  'amazon_close',
#  'amazon_volume',
#  'google_close',
#  'google_volume',
#  'uber_close',
#  'uber_volume']

# %%
df[closes].corr()
# Out:
#                apple_close  apple_volume  amazon_close  amazon_volume  \
# apple_close           1.00         -0.29          0.89          -0.21
# apple_volume         -0.29          1.00         -0.22           0.57
# amazon_close          0.89         -0.22          1.00          -0.17
# amazon_volume        -0.21          0.57         -0.17           1.00
# google_close          0.95         -0.36          0.84          -0.25
# google_volume        -0.08          0.50         -0.09           0.60
# uber_close            0.21         -0.28          0.55          -0.24
# uber_volume           0.13          0.24         -0.06           0.24
#
#                google_close  google_volume  uber_close  uber_volume
# apple_close            0.95          -0.08        0.21         0.13
# apple_volume          -0.36           0.50       -0.28         0.24
# amazon_close           0.84          -0.09        0.55        -0.06
# amazon_volume         -0.25           0.60       -0.24         0.24
# google_close           1.00          -0.12        0.27         0.10
# google_volume         -0.12           1.00       -0.22         0.26
# uber_close             0.27          -0.22        1.00        -0.26
# uber_volume            0.10           0.26       -0.26         1.00

# %% [markdown]
# # **Metoda append()**

# %%
uber.head()
# Out:
#             uber_open  uber_high  uber_low  uber_close  uber_volume
# Date
# 2022-08-05      31.20      32.63     31.04       32.01     39963623
# 2022-08-04      29.78      32.23     29.60       31.85     55573597
# 2022-08-03      29.72      31.43     29.36       30.19     62061199
# 2022-08-02      28.49      29.43     27.10       29.25    107926256
# 2022-08-01      23.43      24.62     22.89       24.60     46960678

# %%
uber_6 = uber[uber.index.month == 6]
uber_6
# Out:
#             uber_open  uber_high  uber_low  uber_close  uber_volume
# Date
# 2022-06-30      21.11      21.13     19.89       20.46     30882454
# 2022-06-29      22.11      22.15     21.08       21.47     30704792
# 2022-06-28      22.97      23.46     22.04       22.08     24360150
# 2022-06-27      23.45      23.64     22.34       22.86     27153354
# 2022-06-24      22.48      23.19     22.30       23.03     38140098
# ...               ...        ...       ...         ...          ...
# 2019-06-07      44.92      45.67     44.13       44.16     12654670
# 2019-06-06      45.00      45.75     44.28       44.92     16403691
# 2019-06-05      42.87      45.66     42.50       45.00     28609604
# 2019-06-04      42.56      42.88     40.70       42.75     23432141
# 2019-06-03      40.74      41.85     40.24       41.25     16605261
#
# [85 rows x 5 columns]

# %%
uber_7 = uber[uber.index.month == 7]
uber_7
# Out:
#             uber_open  uber_high  uber_low  uber_close  uber_volume
# Date
# 2022-07-29      23.18      23.48     22.39       23.45     29406649
# 2022-07-28      22.89      23.42     22.14       23.31     22886075
# 2022-07-27      23.00      23.32     22.49       23.09     28384348
# 2022-07-26      23.15      23.15     22.45       22.55     24402801
# 2022-07-25      23.27      23.54     22.63       23.35     12923042
# ...               ...        ...       ...         ...          ...
# 2019-07-08      43.59      43.85     42.75       42.95      9304101
# 2019-07-05      44.31      44.55     43.01       43.53      8239452
# 2019-07-03      44.00      44.46     43.79       44.23      3380003
# 2019-07-02      44.55      44.68     43.75       44.00     11881274
# 2019-07-01      46.98      47.04     44.06       44.27     17739998
#
# [85 rows x 5 columns]

# %%
uber_6_7 = uber_6.append(uber_7)
uber_6_7
# Out:
#             uber_open  uber_high  uber_low  uber_close  uber_volume
# Date
# 2022-06-30      21.11      21.13     19.89       20.46     30882454
# 2022-06-29      22.11      22.15     21.08       21.47     30704792
# 2022-06-28      22.97      23.46     22.04       22.08     24360150
# 2022-06-27      23.45      23.64     22.34       22.86     27153354
# 2022-06-24      22.48      23.19     22.30       23.03     38140098
# ...               ...        ...       ...         ...          ...
# 2019-07-08      43.59      43.85     42.75       42.95      9304101
# 2019-07-05      44.31      44.55     43.01       43.53      8239452
# 2019-07-03      44.00      44.46     43.79       44.23      3380003
# 2019-07-02      44.55      44.68     43.75       44.00     11881274
# 2019-07-01      46.98      47.04     44.06       44.27     17739998
#
# [170 rows x 5 columns]
